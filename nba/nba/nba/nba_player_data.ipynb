# %%
import requests
import json
import pprint
import pandas as pd
import pycurl
from itertools import chain
pp = pprint.PrettyPrinter()

# %%
# This is an example of one pull from the balldontlie.io API for a player searched by name
# You can see that lebron james was added as a search term at the end, and we can replicate this with other players
# The goal being to isolate the id's to use later for performance statistics
# Next we will be creating a for loop to get all of the players from our salaries list

# %%
# As you can see in this example, any capitalization does not matter for the player search
james = requests.get("https://www.balldontlie.io/api/v1/players/?search=LEbron jaMes")
james.json()
# Out:
# {'data': [{'id': 237,
#    'first_name': 'LeBron',
#    'height_feet': 6,
#    'height_inches': 8,
#    'last_name': 'James',
#    'position': 'F',
#    'team': {'id': 14,
#     'abbreviation': 'LAL',
#     'city': 'Los Angeles',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Los Angeles Lakers',
#     'name': 'Lakers'},
#    'weight_pounds': 250}],
#  'meta': {'total_pages': 1,
#   'current_page': 1,
#   'next_page': None,
#   'per_page': 25,
#   'total_count': 1}}

# %%
# We take the file from BDLio and convert it to a dictionary so we car parse the ID
james_dict = json.loads(james.text)
print(james_dict)
type(james_dict)
# Out:
# {'data': [{'id': 237, 'first_name': 'LeBron', 'height_feet': 6, 'height_inches': 8, 'last_name': 'James', 'position': 'F', 'team': {'id': 14, 'abbreviation': 'LAL', 'city': 'Los Angeles', 'conference': 'West', 'division': 'Pacific', 'full_name': 'Los Angeles Lakers', 'name': 'Lakers'}, 'weight_pounds': 250}], 'meta': {'total_pages': 1, 'current_page': 1, 'next_page': None, 'per_page': 25, 'total_count': 1}}
# dict

# %%
james_id = james_dict['data'][0]["id"]

# %%
# %store -r player_names_list
player_names_list
# Out:
# ['Stephen Curry',
#  'John Wall',
#  'Russell Westbrook',
#  'James Harden',
#  'Damian Lillard',
#  'LeBron James',
#  'Kevin Durant',
#  'Giannis Antetokounmpo',
#  'Paul George',
#  'Kawhi Leonard',
#  'Klay Thompson',
#  'Jimmy Butler',
#  'Tobias Harris',
#  'Khris Middleton',
#  'Anthony Davis',
#  'Rudy Gobert',
#  'Kyrie Irving',
#  'Bradley Beal',
#  'Kristaps Porzingis',
#  'Devin Booker']

# %%
url = "https://www.balldontlie.io/api/v1/players/?search="
player_id_list = []

for name in player_names_list:
    player_url = url + f"{name}"
    player_get = requests.get(player_url)
    player_get.json()
    player_dict = json.loads(player_get.text)
    player_id_list.append(player_dict['data'][0]["id"])
print(player_id_list)
# Out:
# [115, 1014, 472, 192, 278, 237, 140, 15, 172, 274, 443, 79, 200, 315, 117, 176, 228, 37, 378, 57]

# %%
averages_url = "https://www.balldontlie.io/api/v1/season_averages?player_ids[]="
averages_list = []
for ids in player_id_list:
    averages_new = averages_url + f"{str(ids)}"
    averages_get = requests.get(averages_new)
    averages_get.json()
    averages_dict = json.loads(averages_get.text)
    print(averages_dict)
    if ids == 57:
        break
# Out:
# {'data': [{'games_played': 11, 'player_id': 115, 'season': 2021, 'min': '32:19', 'fgm': 8.27, 'fga': 19.27, 'fg3m': 5.0, 'fg3a': 12.73, 'ftm': 4.73, 'fta': 4.82, 'oreb': 0.82, 'dreb': 5.64, 'reb': 6.45, 'ast': 6.45, 'stl': 1.73, 'blk': 0.55, 'turnover': 3.18, 'pf': 1.36, 'pts': 26.27, 'fg_pct': 0.429, 'fg3_pct': 0.393, 'ft_pct': 0.981}]}
# {'data': []}
# {'data': [{'games_played': 11, 'player_id': 472, 'season': 2021, 'min': '35:40', 'fgm': 7.36, 'fga': 17.91, 'fg3m': 1.0, 'fg3a': 3.91, 'ftm': 3.09, 'fta': 4.82, 'oreb': 1.64, 'dreb': 7.18, 'reb': 8.82, 'ast': 8.45, 'stl': 1.55, 'blk': 0.09, 'turnover': 5.09, 'pf': 3.27, 'pts': 18.82, 'fg_pct': 0.411, 'fg3_pct': 0.256, 'ft_pct': 0.642}]}
# {'data': [{'games_played': 12, 'player_id': 192, 'season': 2021, 'min': '31:26', 'fgm': 5.08, 'fga': 12.75, 'fg3m': 2.83, 'fg3a': 7.08, 'ftm': 3.75, 'fta': 4.25, 'oreb': 1.08, 'dreb': 6.0, 'reb': 7.08, 'ast': 7.83, 'stl': 0.92, 'blk': 0.83, 'turnover': 4.17, 'pf': 2.25, 'pts': 16.75, 'fg_pct': 0.399, 'fg3_pct': 0.4, 'ft_pct': 0.882}]}
# {'data': [{'games_played': 12, 'player_id': 278, 'season': 2021, 'min': '33:11', 'fgm': 6.92, 'fga': 18.25, 'fg3m': 2.75, 'fg3a': 9.75, 'ftm': 2.67, 'fta': 3.08, 'oreb': 0.33, 'dreb': 3.58, 'reb': 3.92, 'ast': 7.75, 'stl': 0.67, 'blk': 0.08, 'turnover': 2.5, 'pf': 1.75, 'pts': 19.25, 'fg_pct': 0.379, 'fg3_pct': 0.282, 'ft_pct': 0.865}]}
# {'data': [{'games_played': 6, 'player_id': 237, 'season': 2021, 'min': '37:03', 'fgm': 9.5, 'fga': 20.33, 'fg3m': 2.83, 'fg3a': 8.17, 'ftm': 3.0, 'fta': 3.83, 'oreb': 0.5, 'dreb': 5.0, 'reb': 5.5, 'ast': 7.0, 'stl': 2.33, 'blk': 0.83, 'turnover': 4.17, 'pf': 2.33, 'pts': 24.83, 'fg_pct': 0.467, 'fg3_pct': 0.347, 'ft_pct': 0.783}]}
# {'data': [{'games_played': 12, 'player_id': 140, 'season': 2021, 'min': '32:01', 'fgm': 10.25, 'fga': 18.08, 'fg3m': 1.75, 'fg3a': 4.58, 'ftm': 4.75, 'fta': 5.75, 'oreb': 0.5, 'dreb': 7.5, 'reb': 8.0, 'ast': 4.83, 'stl': 0.58, 'blk': 0.67, 'turnover': 3.0, 'pf': 1.25, 'pts': 27.0, 'fg_pct': 0.567, 'fg3_pct': 0.382, 'ft_pct': 0.826}]}
# {'data': [{'games_played': 12, 'player_id': 15, 'season': 2021, 'min': '29:44', 'fgm': 9.08, 'fga': 17.92, 'fg3m': 1.17, 'fg3a': 4.25, 'ftm': 6.0, 'fta': 8.75, 'oreb': 1.75, 'dreb': 8.83, 'reb': 10.58, 'ast': 5.33, 'stl': 1.0, 'blk': 1.58, 'turnover': 2.75, 'pf': 2.67, 'pts': 25.33, 'fg_pct': 0.507, 'fg3_pct': 0.275, 'ft_pct': 0.686}]}
# {'data': [{'games_played': 10, 'player_id': 172, 'season': 2021, 'min': '35:01', 'fgm': 9.9, 'fga': 21.6, 'fg3m': 3.2, 'fg3a': 8.8, 'ftm': 3.7, 'fta': 4.3, 'oreb': 0.4, 'dreb': 7.9, 'reb': 8.3, 'ast': 5.4, 'stl': 2.5, 'blk': 0.5, 'turnover': 4.6, 'pf': 3.0, 'pts': 26.7, 'fg_pct': 0.458, 'fg3_pct': 0.364, 'ft_pct': 0.86}]}
# {'data': []}
# {'data': []}
# {'data': [{'games_played': 10, 'player_id': 79, 'season': 2021, 'min': '35:05', 'fgm': 8.7, 'fga': 16.4, 'fg3m': 0.5, 'fg3a': 1.6, 'ftm': 7.4, 'fta': 8.8, 'oreb': 1.9, 'dreb': 4.1, 'reb': 6.0, 'ast': 5.5, 'stl': 2.1, 'blk': 0.4, 'turnover': 2.1, 'pf': 2.2, 'pts': 25.3, 'fg_pct': 0.53, 'fg3_pct': 0.313, 'ft_pct': 0.841}]}
# {'data': [{'games_played': 6, 'player_id': 200, 'season': 2021, 'min': '33:03', 'fgm': 8.5, 'fga': 15.67, 'fg3m': 1.33, 'fg3a': 4.17, 'ftm': 1.5, 'fta': 1.67, 'oreb': 1.33, 'dreb': 7.67, 'reb': 9.0, 'ast': 4.17, 'stl': 0.17, 'blk': 0.33, 'turnover': 1.5, 'pf': 1.17, 'pts': 19.83, 'fg_pct': 0.543, 'fg3_pct': 0.32, 'ft_pct': 0.9}]}
# {'data': [{'games_played': 6, 'player_id': 315, 'season': 2021, 'min': '31:27', 'fgm': 7.33, 'fga': 17.0, 'fg3m': 1.5, 'fg3a': 5.83, 'ftm': 3.83, 'fta': 4.5, 'oreb': 0.5, 'dreb': 4.17, 'reb': 4.67, 'ast': 4.5, 'stl': 2.0, 'blk': 0.17, 'turnover': 3.5, 'pf': 2.17, 'pts': 20.0, 'fg_pct': 0.431, 'fg3_pct': 0.257, 'ft_pct': 0.852}]}
# {'data': [{'games_played': 11, 'player_id': 117, 'season': 2021, 'min': '34:01', 'fgm': 9.64, 'fga': 19.18, 'fg3m': 0.27, 'fg3a': 2.18, 'ftm': 4.36, 'fta': 5.91, 'oreb': 3.73, 'dreb': 7.36, 'reb': 11.09, 'ast': 2.73, 'stl': 1.0, 'blk': 2.36, 'turnover': 2.27, 'pf': 2.18, 'pts': 23.91, 'fg_pct': 0.502, 'fg3_pct': 0.125, 'ft_pct': 0.738}]}
# {'data': [{'games_played': 12, 'player_id': 176, 'season': 2021, 'min': '28:13', 'fgm': 4.5, 'fga': 6.25, 'fg3m': 0.0, 'fg3a': 0.0, 'ftm': 4.42, 'fta': 6.67, 'oreb': 3.08, 'dreb': 11.5, 'reb': 14.58, 'ast': 0.92, 'stl': 1.0, 'blk': 1.75, 'turnover': 2.08, 'pf': 2.58, 'pts': 13.42, 'fg_pct': 0.72, 'fg3_pct': 0, 'ft_pct': 0.663}]}
# {'data': []}
# {'data': [{'games_played': 10, 'player_id': 37, 'season': 2021, 'min': '32:14', 'fgm': 8.4, 'fga': 19.7, 'fg3m': 1.5, 'fg3a': 5.9, 'ftm': 3.5, 'fta': 3.6, 'oreb': 0.7, 'dreb': 4.1, 'reb': 4.8, 'ast': 4.9, 'stl': 1.2, 'blk': 0.5, 'turnover': 3.6, 'pf': 1.5, 'pts': 21.8, 'fg_pct': 0.426, 'fg3_pct': 0.254, 'ft_pct': 0.972}]}
# {'data': [{'games_played': 5, 'player_id': 378, 'season': 2021, 'min': '26:17', 'fgm': 4.8, 'fga': 13.8, 'fg3m': 1.4, 'fg3a': 5.6, 'ftm': 3.2, 'fta': 4.0, 'oreb': 1.8, 'dreb': 4.8, 'reb': 6.6, 'ast': 1.4, 'stl': 0.8, 'blk': 1.6, 'turnover': 1.6, 'pf': 2.4, 'pts': 14.2, 'fg_pct': 0.348, 'fg3_pct': 0.25, 'ft_pct': 0.8}]}
# {'data': [{'games_played': 10, 'player_id': 57, 'season': 2021, 'min': '29:47', 'fgm': 7.9, 'fga': 17.7, 'fg3m': 2.1, 'fg3a': 5.8, 'ftm': 3.5, 'fta': 4.3, 'oreb': 1.1, 'dreb': 4.4, 'reb': 5.5, 'ast': 4.7, 'stl': 1.0, 'blk': 0.3, 'turnover': 2.8, 'pf': 2.5, 'pts': 21.4, 'fg_pct': 0.446, 'fg3_pct': 0.362, 'ft_pct': 0.814}]}

# %%
averages_url = "https://www.balldontlie.io/api/v1/season_averages?player_ids[]="
averages_list = []
for ids in player_id_list:
    averages_new = averages_url + f"{str(ids)}"
    averages_get = requests.get(averages_new)
    averages_get.json()
    averages_dict = json.loads(averages_get.text)
    averages_list.append(averages_dict['data'])
    if ids == 57:
        break
averages_list
# Out:
# [[{'games_played': 11,
#    'player_id': 115,
#    'season': 2021,
#    'min': '32:19',
#    'fgm': 8.27,
#    'fga': 19.27,
#    'fg3m': 5.0,
#    'fg3a': 12.73,
#    'ftm': 4.73,
#    'fta': 4.82,
#    'oreb': 0.82,
#    'dreb': 5.64,
#    'reb': 6.45,
#    'ast': 6.45,
#    'stl': 1.73,
#    'blk': 0.55,
#    'turnover': 3.18,
#    'pf': 1.36,
#    'pts': 26.27,
#    'fg_pct': 0.429,
#    'fg3_pct': 0.393,
#    'ft_pct': 0.981}],
#  [],
#  [{'games_played': 11,
#    'player_id': 472,
#    'season': 2021,
#    'min': '35:40',
#    'fgm': 7.36,
#    'fga': 17.91,
#    'fg3m': 1.0,
#    'fg3a': 3.91,
#    'ftm': 3.09,
#    'fta': 4.82,
#    'oreb': 1.64,
#    'dreb': 7.18,
#    'reb': 8.82,
#    'ast': 8.45,
#    'stl': 1.55,
#    'blk': 0.09,
#    'turnover': 5.09,
#    'pf': 3.27,
#    'pts': 18.82,
#    'fg_pct': 0.411,
#    'fg3_pct': 0.256,
#    'ft_pct': 0.642}],
#  [{'games_played': 12,
#    'player_id': 192,
#    'season': 2021,
#    'min': '31:52',
#    'fgm': 5.25,
#    'fga': 12.92,
#    'fg3m': 2.92,
#    'fg3a': 7.17,
#    'ftm': 3.75,
#    'fta': 4.25,
#    'oreb': 1.08,
#    'dreb': 6.08,
#    'reb': 7.17,
#    'ast': 8.08,
#    'stl': 0.92,
#    'blk': 0.83,
#    'turnover': 4.33,
#    'pf': 2.25,
#    'pts': 17.17,
#    'fg_pct': 0.406,
#    'fg3_pct': 0.407,
#    'ft_pct': 0.882}],
#  [{'games_played': 12,
#    'player_id': 278,
#    'season': 2021,
#    'min': '33:11',
#    'fgm': 6.92,
#    'fga': 18.25,
#    'fg3m': 2.75,
#    'fg3a': 9.75,
#    'ftm': 2.67,
#    'fta': 3.08,
#    'oreb': 0.33,
#    'dreb': 3.58,
#    'reb': 3.92,
#    'ast': 7.75,
#    'stl': 0.67,
#    'blk': 0.08,
#    'turnover': 2.5,
#    'pf': 1.75,
#    'pts': 19.25,
#    'fg_pct': 0.379,
#    'fg3_pct': 0.282,
#    'ft_pct': 0.865}],
#  [{'games_played': 6,
#    'player_id': 237,
#    'season': 2021,
#    'min': '37:03',
#    'fgm': 9.5,
#    'fga': 20.33,
#    'fg3m': 2.83,
#    'fg3a': 8.17,
#    'ftm': 3.0,
#    'fta': 3.83,
#    'oreb': 0.5,
#    'dreb': 5.0,
#    'reb': 5.5,
#    'ast': 7.0,
#    'stl': 2.33,
#    'blk': 0.83,
#    'turnover': 4.17,
#    'pf': 2.33,
#    'pts': 24.83,
#    'fg_pct': 0.467,
#    'fg3_pct': 0.347,
#    'ft_pct': 0.783}],
#  [{'games_played': 12,
#    'player_id': 140,
#    'season': 2021,
#    'min': '32:27',
#    'fgm': 10.42,
#    'fga': 18.25,
#    'fg3m': 1.83,
#    'fg3a': 4.67,
#    'ftm': 4.75,
#    'fta': 5.75,
#    'oreb': 0.5,
#    'dreb': 7.67,
#    'reb': 8.17,
#    'ast': 4.83,
#    'stl': 0.58,
#    'blk': 0.67,
#    'turnover': 3.0,
#    'pf': 1.25,
#    'pts': 27.42,
#    'fg_pct': 0.571,
#    'fg3_pct': 0.393,
#    'ft_pct': 0.826}],
#  [{'games_played': 12,
#    'player_id': 15,
#    'season': 2021,
#    'min': '29:44',
#    'fgm': 9.08,
#    'fga': 17.92,
#    'fg3m': 1.17,
#    'fg3a': 4.25,
#    'ftm': 6.0,
#    'fta': 8.75,
#    'oreb': 1.75,
#    'dreb': 8.83,
#    'reb': 10.58,
#    'ast': 5.33,
#    'stl': 1.0,
#    'blk': 1.58,
#    'turnover': 2.75,
#    'pf': 2.67,
#    'pts': 25.33,
#    'fg_pct': 0.507,
#    'fg3_pct': 0.275,
#    'ft_pct': 0.686}],
#  [{'games_played': 10,
#    'player_id': 172,
#    'season': 2021,
#    'min': '35:01',
#    'fgm': 9.9,
#    'fga': 21.6,
#    'fg3m': 3.2,
#    'fg3a': 8.8,
#    'ftm': 3.7,
#    'fta': 4.3,
#    'oreb': 0.4,
#    'dreb': 7.9,
#    'reb': 8.3,
#    'ast': 5.4,
#    'stl': 2.5,
#    'blk': 0.5,
#    'turnover': 4.6,
#    'pf': 3.0,
#    'pts': 26.7,
#    'fg_pct': 0.458,
#    'fg3_pct': 0.364,
#    'ft_pct': 0.86}],
#  [],
#  [],
#  [{'games_played': 10,
#    'player_id': 79,
#    'season': 2021,
#    'min': '35:05',
#    'fgm': 8.7,
#    'fga': 16.4,
#    'fg3m': 0.5,
#    'fg3a': 1.6,
#    'ftm': 7.4,
#    'fta': 8.8,
#    'oreb': 1.9,
#    'dreb': 4.1,
#    'reb': 6.0,
#    'ast': 5.5,
#    'stl': 2.1,
#    'blk': 0.4,
#    'turnover': 2.1,
#    'pf': 2.2,
#    'pts': 25.3,
#    'fg_pct': 0.53,
#    'fg3_pct': 0.313,
#    'ft_pct': 0.841}],
#  [{'games_played': 6,
#    'player_id': 200,
#    'season': 2021,
#    'min': '33:03',
#    'fgm': 8.5,
#    'fga': 15.67,
#    'fg3m': 1.33,
#    'fg3a': 4.17,
#    'ftm': 1.5,
#    'fta': 1.67,
#    'oreb': 1.33,
#    'dreb': 7.67,
#    'reb': 9.0,
#    'ast': 4.17,
#    'stl': 0.17,
#    'blk': 0.33,
#    'turnover': 1.5,
#    'pf': 1.17,
#    'pts': 19.83,
#    'fg_pct': 0.543,
#    'fg3_pct': 0.32,
#    'ft_pct': 0.9}],
#  [{'games_played': 6,
#    'player_id': 315,
#    'season': 2021,
#    'min': '31:27',
#    'fgm': 7.33,
#    'fga': 17.0,
#    'fg3m': 1.5,
#    'fg3a': 5.83,
#    'ftm': 3.83,
#    'fta': 4.5,
#    'oreb': 0.5,
#    'dreb': 4.17,
#    'reb': 4.67,
#    'ast': 4.5,
#    'stl': 2.0,
#    'blk': 0.17,
#    'turnover': 3.5,
#    'pf': 2.17,
#    'pts': 20.0,
#    'fg_pct': 0.431,
#    'fg3_pct': 0.257,
#    'ft_pct': 0.852}],
#  [{'games_played': 11,
#    'player_id': 117,
#    'season': 2021,
#    'min': '34:01',
#    'fgm': 9.64,
#    'fga': 19.18,
#    'fg3m': 0.27,
#    'fg3a': 2.18,
#    'ftm': 4.36,
#    'fta': 5.91,
#    'oreb': 3.73,
#    'dreb': 7.36,
#    'reb': 11.09,
#    'ast': 2.73,
#    'stl': 1.0,
#    'blk': 2.36,
#    'turnover': 2.27,
#    'pf': 2.18,
#    'pts': 23.91,
#    'fg_pct': 0.502,
#    'fg3_pct': 0.125,
#    'ft_pct': 0.738}],
#  [{'games_played': 12,
#    'player_id': 176,
#    'season': 2021,
#    'min': '28:13',
#    'fgm': 4.5,
#    'fga': 6.25,
#    'fg3m': 0.0,
#    'fg3a': 0.0,
#    'ftm': 4.42,
#    'fta': 6.67,
#    'oreb': 3.08,
#    'dreb': 11.5,
#    'reb': 14.58,
#    'ast': 0.92,
#    'stl': 1.0,
#    'blk': 1.75,
#    'turnover': 2.08,
#    'pf': 2.58,
#    'pts': 13.42,
#    'fg_pct': 0.72,
#    'fg3_pct': 0,
#    'ft_pct': 0.663}],
#  [],
#  [{'games_played': 10,
#    'player_id': 37,
#    'season': 2021,
#    'min': '32:46',
#    'fgm': 8.4,
#    'fga': 19.9,
#    'fg3m': 1.5,
#    'fg3a': 5.9,
#    'ftm': 3.7,
#    'fta': 3.8,
#    'oreb': 0.7,
#    'dreb': 4.3,
#    'reb': 5.0,
#    'ast': 4.9,
#    'stl': 1.2,
#    'blk': 0.5,
#    'turnover': 3.6,
#    'pf': 1.5,
#    'pts': 22.0,
#    'fg_pct': 0.422,
#    'fg3_pct': 0.254,
#    'ft_pct': 0.974}],
#  [{'games_played': 5,
#    'player_id': 378,
#    'season': 2021,
#    'min': '26:17',
#    'fgm': 4.8,
#    'fga': 13.8,
#    'fg3m': 1.4,
#    'fg3a': 5.6,
#    'ftm': 3.2,
#    'fta': 4.0,
#    'oreb': 1.8,
#    'dreb': 4.8,
#    'reb': 6.6,
#    'ast': 1.4,
#    'stl': 0.8,
#    'blk': 1.6,
#    'turnover': 1.6,
#    'pf': 2.4,
#    'pts': 14.2,
#    'fg_pct': 0.348,
#    'fg3_pct': 0.25,
#    'ft_pct': 0.8}],
#  [{'games_played': 10,
#    'player_id': 57,
#    'season': 2021,
#    'min': '29:47',
#    'fgm': 7.9,
#    'fga': 17.7,
#    'fg3m': 2.1,
#    'fg3a': 5.8,
#    'ftm': 3.5,
#    'fta': 4.3,
#    'oreb': 1.1,
#    'dreb': 4.4,
#    'reb': 5.5,
#    'ast': 4.7,
#    'stl': 1.0,
#    'blk': 0.3,
#    'turnover': 2.8,
#    'pf': 2.5,
#    'pts': 21.4,
#    'fg_pct': 0.446,
#    'fg3_pct': 0.362,
#    'ft_pct': 0.814}]]

# %%
averages_df = pd.DataFrame(list(chain.from_iterable(averages_list)))
averages_df
# Out:
#     games_played  player_id  season    min    fgm    fga  fg3m   fg3a   ftm  \
# 0             11        115    2021  32:19   8.27  19.27  5.00  12.73  4.73
# 1             11        472    2021  35:40   7.36  17.91  1.00   3.91  3.09
# 2             12        192    2021  31:52   5.25  12.92  2.92   7.17  3.75
# 3             12        278    2021  33:11   6.92  18.25  2.75   9.75  2.67
# 4              6        237    2021  37:03   9.50  20.33  2.83   8.17  3.00
# 5             12        140    2021  32:27  10.42  18.25  1.83   4.67  4.75
# 6             12         15    2021  29:44   9.08  17.92  1.17   4.25  6.00
# 7             10        172    2021  35:01   9.90  21.60  3.20   8.80  3.70
# 8             10         79    2021  35:05   8.70  16.40  0.50   1.60  7.40
# 9              6        200    2021  33:03   8.50  15.67  1.33   4.17  1.50
# 10             6        315    2021  31:27   7.33  17.00  1.50   5.83  3.83
# 11            11        117    2021  34:01   9.64  19.18  0.27   2.18  4.36
# 12            12        176    2021  28:13   4.50   6.25  0.00   0.00  4.42
# 13            10         37    2021  32:46   8.40  19.90  1.50   5.90  3.70
# 14             5        378    2021  26:17   4.80  13.80  1.40   5.60  3.20
# 15            10         57    2021  29:47   7.90  17.70  2.10   5.80  3.50
#
#      fta  ...    reb   ast   stl   blk  turnover    pf    pts  fg_pct  \
# 0   4.82  ...   6.45  6.45  1.73  0.55      3.18  1.36  26.27   0.429
# 1   4.82  ...   8.82  8.45  1.55  0.09      5.09  3.27  18.82   0.411
# 2   4.25  ...   7.17  8.08  0.92  0.83      4.33  2.25  17.17   0.406
# 3   3.08  ...   3.92  7.75  0.67  0.08      2.50  1.75  19.25   0.379
# 4   3.83  ...   5.50  7.00  2.33  0.83      4.17  2.33  24.83   0.467
# 5   5.75  ...   8.17  4.83  0.58  0.67      3.00  1.25  27.42   0.571
# 6   8.75  ...  10.58  5.33  1.00  1.58      2.75  2.67  25.33   0.507
# 7   4.30  ...   8.30  5.40  2.50  0.50      4.60  3.00  26.70   0.458
# 8   8.80  ...   6.00  5.50  2.10  0.40      2.10  2.20  25.30   0.530
# 9   1.67  ...   9.00  4.17  0.17  0.33      1.50  1.17  19.83   0.543
# 10  4.50  ...   4.67  4.50  2.00  0.17      3.50  2.17  20.00   0.431
# 11  5.91  ...  11.09  2.73  1.00  2.36      2.27  2.18  23.91   0.502
# 12  6.67  ...  14.58  0.92  1.00  1.75      2.08  2.58  13.42   0.720
# 13  3.80  ...   5.00  4.90  1.20  0.50      3.60  1.50  22.00   0.422
# 14  4.00  ...   6.60  1.40  0.80  1.60      1.60  2.40  14.20   0.348
# 15  4.30  ...   5.50  4.70  1.00  0.30      2.80  2.50  21.40   0.446
#
#     fg3_pct  ft_pct
# 0     0.393   0.981
# 1     0.256   0.642
# 2     0.407   0.882
# 3     0.282   0.865
# 4     0.347   0.783
# 5     0.393   0.826
# 6     0.275   0.686
# 7     0.364   0.860
# 8     0.313   0.841
# 9     0.320   0.900
# 10    0.257   0.852
# 11    0.125   0.738
# 12    0.000   0.663
# 13    0.254   0.974
# 14    0.250   0.800
# 15    0.362   0.814
#
# [16 rows x 22 columns]

# %%
# %store -r salary_df
salary_df
# Out:
#     Rk                 Player   Tm       2021-22
# 0    1          Stephen Curry  GSW  $45780966.00
# 1    2              John Wall  HOU  $44310840.00
# 2    3      Russell Westbrook  LAL  $44211146.00
# 3    4           James Harden  BRK  $43848000.00
# 4    5         Damian Lillard  POR  $43750000.00
# 5    6           LeBron James  LAL  $41180544.00
# 6    7           Kevin Durant  BRK  $40918900.00
# 7    8  Giannis Antetokounmpo  MIL  $39344970.00
# 8    9            Paul George  LAC  $39344970.00
# 9   10          Kawhi Leonard  LAC  $39344900.00
# 10  11          Klay Thompson  GSW  $37980720.00
# 11  12           Jimmy Butler  MIA  $36016200.00
# 12  13          Tobias Harris  PHI  $36000000.00
# 13  14        Khris Middleton  MIL  $35500000.00
# 14  15          Anthony Davis  LAL  $35361360.00
# 15  16            Rudy Gobert  UTA  $35344828.00
# 16  17           Kyrie Irving  BRK  $34916200.00
# 17  18           Bradley Beal  WAS  $34502130.00
# 18  19     Kristaps Porzingis  DAL  $31650600.00
# 19  20           Devin Booker  PHO  $31610000.00

# %%
player_id_df = pd.DataFrame(player_id_list)
salary_id_join = player_id_df.join(salary_df)
salary_id_join
# Out:
#        0  Rk                 Player   Tm       2021-22
# 0    115   1          Stephen Curry  GSW  $45780966.00
# 1   1014   2              John Wall  HOU  $44310840.00
# 2    472   3      Russell Westbrook  LAL  $44211146.00
# 3    192   4           James Harden  BRK  $43848000.00
# 4    278   5         Damian Lillard  POR  $43750000.00
# 5    237   6           LeBron James  LAL  $41180544.00
# 6    140   7           Kevin Durant  BRK  $40918900.00
# 7     15   8  Giannis Antetokounmpo  MIL  $39344970.00
# 8    172   9            Paul George  LAC  $39344970.00
# 9    274  10          Kawhi Leonard  LAC  $39344900.00
# 10   443  11          Klay Thompson  GSW  $37980720.00
# 11    79  12           Jimmy Butler  MIA  $36016200.00
# 12   200  13          Tobias Harris  PHI  $36000000.00
# 13   315  14        Khris Middleton  MIL  $35500000.00
# 14   117  15          Anthony Davis  LAL  $35361360.00
# 15   176  16            Rudy Gobert  UTA  $35344828.00
# 16   228  17           Kyrie Irving  BRK  $34916200.00
# 17    37  18           Bradley Beal  WAS  $34502130.00
# 18   378  19     Kristaps Porzingis  DAL  $31650600.00
# 19    57  20           Devin Booker  PHO  $31610000.00

# %%
salary_player_id_df = salary_id_join.rename(columns={0: 'player_id'})
salary_player_id_df
# Out:
#     player_id  Rk                 Player   Tm       2021-22
# 0         115   1          Stephen Curry  GSW  $45780966.00
# 1        1014   2              John Wall  HOU  $44310840.00
# 2         472   3      Russell Westbrook  LAL  $44211146.00
# 3         192   4           James Harden  BRK  $43848000.00
# 4         278   5         Damian Lillard  POR  $43750000.00
# 5         237   6           LeBron James  LAL  $41180544.00
# 6         140   7           Kevin Durant  BRK  $40918900.00
# 7          15   8  Giannis Antetokounmpo  MIL  $39344970.00
# 8         172   9            Paul George  LAC  $39344970.00
# 9         274  10          Kawhi Leonard  LAC  $39344900.00
# 10        443  11          Klay Thompson  GSW  $37980720.00
# 11         79  12           Jimmy Butler  MIA  $36016200.00
# 12        200  13          Tobias Harris  PHI  $36000000.00
# 13        315  14        Khris Middleton  MIL  $35500000.00
# 14        117  15          Anthony Davis  LAL  $35361360.00
# 15        176  16            Rudy Gobert  UTA  $35344828.00
# 16        228  17           Kyrie Irving  BRK  $34916200.00
# 17         37  18           Bradley Beal  WAS  $34502130.00
# 18        378  19     Kristaps Porzingis  DAL  $31650600.00
# 19         57  20           Devin Booker  PHO  $31610000.00

# %%
salary_player_id_df.merge(averages_df, on='player_id', how='right')
# Out:
#     player_id  Rk                 Player   Tm       2021-22  games_played  \
# 0         115   1          Stephen Curry  GSW  $45780966.00            11
# 1         472   3      Russell Westbrook  LAL  $44211146.00            11
# 2         192   4           James Harden  BRK  $43848000.00            12
# 3         278   5         Damian Lillard  POR  $43750000.00            12
# 4         237   6           LeBron James  LAL  $41180544.00             6
# 5         140   7           Kevin Durant  BRK  $40918900.00            12
# 6          15   8  Giannis Antetokounmpo  MIL  $39344970.00            12
# 7         172   9            Paul George  LAC  $39344970.00            10
# 8          79  12           Jimmy Butler  MIA  $36016200.00            10
# 9         200  13          Tobias Harris  PHI  $36000000.00             6
# 10        315  14        Khris Middleton  MIL  $35500000.00             6
# 11        117  15          Anthony Davis  LAL  $35361360.00            11
# 12        176  16            Rudy Gobert  UTA  $35344828.00            12
# 13         37  18           Bradley Beal  WAS  $34502130.00            10
# 14        378  19     Kristaps Porzingis  DAL  $31650600.00             5
# 15         57  20           Devin Booker  PHO  $31610000.00            10
#
#     season    min    fgm    fga  ...    reb   ast   stl   blk  turnover    pf  \
# 0     2021  32:19   8.27  19.27  ...   6.45  6.45  1.73  0.55      3.18  1.36
# 1     2021  35:40   7.36  17.91  ...   8.82  8.45  1.55  0.09      5.09  3.27
# 2     2021  31:52   5.25  12.92  ...   7.17  8.08  0.92  0.83      4.33  2.25
# 3     2021  33:11   6.92  18.25  ...   3.92  7.75  0.67  0.08      2.50  1.75
# 4     2021  37:03   9.50  20.33  ...   5.50  7.00  2.33  0.83      4.17  2.33
# 5     2021  32:27  10.42  18.25  ...   8.17  4.83  0.58  0.67      3.00  1.25
# 6     2021  29:44   9.08  17.92  ...  10.58  5.33  1.00  1.58      2.75  2.67
# 7     2021  35:01   9.90  21.60  ...   8.30  5.40  2.50  0.50      4.60  3.00
# 8     2021  35:05   8.70  16.40  ...   6.00  5.50  2.10  0.40      2.10  2.20
# 9     2021  33:03   8.50  15.67  ...   9.00  4.17  0.17  0.33      1.50  1.17
# 10    2021  31:27   7.33  17.00  ...   4.67  4.50  2.00  0.17      3.50  2.17
# 11    2021  34:01   9.64  19.18  ...  11.09  2.73  1.00  2.36      2.27  2.18
# 12    2021  28:13   4.50   6.25  ...  14.58  0.92  1.00  1.75      2.08  2.58
# 13    2021  32:46   8.40  19.90  ...   5.00  4.90  1.20  0.50      3.60  1.50
# 14    2021  26:17   4.80  13.80  ...   6.60  1.40  0.80  1.60      1.60  2.40
# 15    2021  29:47   7.90  17.70  ...   5.50  4.70  1.00  0.30      2.80  2.50
#
#       pts  fg_pct  fg3_pct  ft_pct
# 0   26.27   0.429    0.393   0.981
# 1   18.82   0.411    0.256   0.642
# 2   17.17   0.406    0.407   0.882
# 3   19.25   0.379    0.282   0.865
# 4   24.83   0.467    0.347   0.783
# 5   27.42   0.571    0.393   0.826
# 6   25.33   0.507    0.275   0.686
# 7   26.70   0.458    0.364   0.860
# 8   25.30   0.530    0.313   0.841
# 9   19.83   0.543    0.320   0.900
# 10  20.00   0.431    0.257   0.852
# 11  23.91   0.502    0.125   0.738
# 12  13.42   0.720    0.000   0.663
# 13  22.00   0.422    0.254   0.974
# 14  14.20   0.348    0.250   0.800
# 15  21.40   0.446    0.362   0.814
#
# [16 rows x 26 columns]
